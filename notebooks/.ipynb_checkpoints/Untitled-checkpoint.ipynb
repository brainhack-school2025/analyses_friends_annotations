# %%
import sys
sys.path.append("../module")
import load
import importlib
importlib.reload(load)
# Out:
# <module 'load' from '/home/cleode5a7/Desktop/analyses_friends_annotations/notebooks/../module/load.py'>

# %%
df = load.tsv_to_df("/home/cleode5a7/Desktop/analyses_friends_annotations/friends_annotations/annotation_results/TSVpyscene", '-Scenes.tsv')

# %%
df
# Out:
#          onset  duration  onset_frame          episode
# 0        0.000    17.986            1  friends_s01e01a
# 1       17.986     4.705          540  friends_s01e01a
# 2       22.691     4.238          681  friends_s01e01a
# 3       26.928     0.868          808  friends_s01e01a
# 4       27.796     2.269          834  friends_s01e01a
# ...        ...       ...          ...              ...
# 47654  648.282    11.646        19429  friends_s06e24b
# 47655  659.927     6.407        19778  friends_s06e24b
# 47656  666.334     6.407        19970  friends_s06e24b
# 47657  672.741     6.574        20162  friends_s06e24b
# 47658  679.314     6.807        20359  friends_s06e24b
#
# [47659 rows x 4 columns]

# %%
dff = load.tsv_to_df2("../friends_annotations/annotation_results/manual_segmentation")

# %%
dff
# Out:
#      episode  scene  segment  onset  offset  duration  ONbond_location  \
# 0     s1e01a      1        1    0.0    10.0      10.0            False
# 1     s1e01a      2        2   10.0    18.0       8.0            False
# 2     s1e01a      3        3   18.0    55.0      37.0            False
# 3     s1e01a      3        4   55.0   101.0      46.0            False
# 4     s1e01a      3        5  101.0   214.0     113.0            False
# ...      ...    ...      ...    ...     ...       ...              ...
# 6218  s6e24d      7       11  524.0   534.0      10.0            False
# 6219  s6e24d      7       12  534.0   651.0     117.0            False
# 6220  s6e24d      7       13  651.0   657.0       6.0            False
# 6221  s6e24d      7       14  657.0   686.0      29.0            False
# 6222  s6e24d      7       15  686.0   720.0      34.0            False
#
#       ONbond_charact_entry  ONbond_charact_leave  ONbond_time_jump  ...  \
# ...

# %%
df = pd.read_csv('/home/cleode5a7/Desktop/analyses_friends_annotations/friends_annotations/annotation_results/DeepgazeMr/s1/friends_s01e03a_maxpeak_coord.tsv', sep='\t')

# %%
df['h'].min()
# Out:
# 0
