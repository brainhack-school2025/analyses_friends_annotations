# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("/mnt/c/Temp/analyses_friends_annotations/output/manual_segmentation_all.tsv", sep='\t')

# %%
#add frames to onset and offset time
fps = 29.97
df['onset_frame'] = (df['onset']*fps).round().astype(int)
df['offset_frame'] = (df['offset'] * fps).round().astype(int)

# %%
df[df['episode'] == 's1e01a']
# Out:
#    episode  scene  segment  onset  offset  duration  ONbond_location  \
# 0   s1e01a      1        1    0.0    10.0      10.0            False
# 1   s1e01a      2        2   10.0    18.0       8.0            False
# 2   s1e01a      3        3   18.0    55.0      37.0            False
# 3   s1e01a      3        4   55.0   101.0      46.0            False
# 4   s1e01a      3        5  101.0   214.0     113.0            False
# 5   s1e01a      3        6  214.0   324.0     110.0            False
# 6   s1e01a      4        7  324.0   330.0       6.0            False
# 7   s1e01a      5        8  330.0   443.0     113.0             True
# 8   s1e01a      6        9  443.0   445.0       2.0            False
# 9   s1e01a      7       10  445.0   500.0      55.0            False
# 10  s1e01a      7       11  500.0   548.0      48.0            False
# 11  s1e01a      7       12  548.0   580.0      32.0            False
# 12  s1e01a      7       13  580.0   596.0      16.0            False
# 13  s1e01a      7       14  596.0   636.0      40.0            False
# 14  s1e01a      7       15  636.0   646.0      10.0            False
# 15  s1e01a      8       16  646.0   651.0       5.0            False
# 16  s1e01a      9       17  651.0   678.0      27.0             True
# 17  s1e01a     10       18  678.0   684.0       6.0            False
# 18  s1e01a     11       19  684.0   756.0      72.0             True
# 19  s1e01a     11       20  756.0   794.0      38.0            False
# 20  s1e01a     11       21  794.0   836.0      42.0            False
# 21  s1e01a     11       22  836.0   875.0      39.0            False
#
#     ONbond_charact_entry  ONbond_charact_leave  ONbond_time_jump  ...  \
# 0                  False                 False             False  ...
# 1                  False                 False             False  ...
# 2                  False                 False             False  ...
# 3                  False                 False              True  ...
# 4                   True                 False              True  ...
# 5                   True                 False             False  ...
# 6                  False                 False             False  ...
# 7                  False                 False              True  ...
# 8                  False                 False             False  ...
# 9                  False                 False              True  ...
# 10                 False                 False             False  ...
# 11                  True                 False             False  ...
# 12                 False                  True             False  ...
# 13                 False                 False             False  ...
# 14                 False                 False             False  ...
# 15                 False                 False             False  ...
# 16                 False                 False              True  ...
# 17                 False                 False             False  ...
# 18                 False                 False              True  ...
# 19                 False                 False              True  ...
# 20                 False                 False              True  ...
# 21                 False                 False              True  ...
#
#     loc_apt2_Chan_Joey  loc_apt3_Ross  loc_apt4_Pheob_Rach  loc_coffeeshop  \
# 0                False          False                False           False
# 1                False          False                False           False
# 2                False          False                False            True
# 3                False          False                False            True
# 4                False          False                False            True
# 5                False          False                False            True
# 6                False          False                False           False
# 7                False          False                False           False
# 8                False          False                False           False
# 9                False          False                False           False
# 10               False          False                False           False
# 11               False          False                False           False
# 12               False          False                False           False
# 13               False          False                False           False
# 14               False          False                False           False
# 15               False          False                False           False
# 16               False          False                False           False
# 17               False          False                False           False
# 18               False          False                False           False
# 19               False          False                False           False
# 20               False          False                False           False
# 21               False          False                False           False
#
#     loc_outside  loc_other  global_segment  episode_full  onset_frame  \
# 0         False      False               1         s1e01            0
# 1          True      False               2         s1e01          300
# 2         False      False               3         s1e01          539
# 3         False      False               4         s1e01         1648
# 4         False      False               5         s1e01         3027
# 5         False      False               6         s1e01         6414
# 6          True      False               7         s1e01         9710
# 7         False      False               8         s1e01         9890
# 8          True      False               9         s1e01        13277
# 9         False      False              10         s1e01        13337
# 10        False      False              11         s1e01        14985
# 11        False      False              12         s1e01        16424
# 12        False      False              13         s1e01        17383
# 13        False      False              14         s1e01        17862
# 14        False      False              15         s1e01        19061
# 15         True      False              16         s1e01        19361
# 16        False       True              17         s1e01        19510
# 17         True      False              18         s1e01        20320
# 18        False       True              19         s1e01        20499
# 19        False       True              20         s1e01        22657
# 20        False      False              21         s1e01        23796
# 21        False       True              22         s1e01        25055
#
#     offset_frame
# 0            300
# 1            539
# 2           1648
# 3           3027
# 4           6414
# 5           9710
# 6           9890
# 7          13277
# 8          13337
# 9          14985
# 10         16424
# 11         17383
# 12         17862
# 13         19061
# 14         19361
# 15         19510
# 16         20320
# 17         20499
# 18         22657
# 19         23796
# 20         25055
# 21         26224
#
# [22 rows x 33 columns]

# %%
df
# Out:
#      episode  scene  segment  onset  offset  duration  ONbond_location  \
# 0     s1e01a      1        1    0.0    10.0      10.0            False
# 1     s1e01a      2        2   10.0    18.0       8.0            False
# 2     s1e01a      3        3   18.0    55.0      37.0            False
# 3     s1e01a      3        4   55.0   101.0      46.0            False
# 4     s1e01a      3        5  101.0   214.0     113.0            False
# ...      ...    ...      ...    ...     ...       ...              ...
# 6218  s6e24d      7       11  524.0   534.0      10.0            False
# 6219  s6e24d      7       12  534.0   651.0     117.0            False
# 6220  s6e24d      7       13  651.0   657.0       6.0            False
# 6221  s6e24d      7       14  657.0   686.0      29.0            False
# 6222  s6e24d      7       15  686.0   720.0      34.0            False
#
#       ONbond_charact_entry  ONbond_charact_leave  ONbond_time_jump  ...  \
# 0                    False                 False             False  ...
# 1                    False                 False             False  ...
# 2                    False                 False             False  ...
# 3                    False                 False              True  ...
# 4                     True                 False              True  ...
# ...                    ...                   ...               ...  ...
# 6218                  True                 False             False  ...
# 6219                 False                  True             False  ...
# 6220                 False                 False             False  ...
# 6221                  True                 False             False  ...
# 6222                 False                 False              True  ...
#
#       loc_apt2_Chan_Joey  loc_apt3_Ross  loc_apt4_Pheob_Rach  loc_coffeeshop  \
# 0                  False          False                False           False
# 1                  False          False                False           False
# 2                  False          False                False            True
# 3                  False          False                False            True
# 4                  False          False                False            True
# ...                  ...            ...                  ...             ...
# 6218               False          False                False           False
# 6219               False          False                False           False
# 6220               False          False                False           False
# 6221               False          False                False           False
# 6222               False          False                False           False
#
#       loc_outside  loc_other  global_segment  episode_full  onset_frame  \
# 0           False      False               1         s1e01            0
# 1            True      False               2         s1e01          300
# 2           False      False               3         s1e01          539
# 3           False      False               4         s1e01         1648
# 4           False      False               5         s1e01         3027
# ...           ...        ...             ...           ...          ...
# 6218        False      False            6219         s6e24        15704
# 6219        False      False            6220         s6e24        16004
# 6220        False      False            6221         s6e24        19510
# 6221        False      False            6222         s6e24        19690
# 6222        False      False            6223         s6e24        20559
#
#       offset_frame
# 0              300
# 1              539
# 2             1648
# 3             3027
# 4             6414
# ...            ...
# 6218         16004
# 6219         19510
# 6220         19690
# 6221         20559
# 6222         21578
#
# [6223 rows x 33 columns]

# %%
num_segments = df.groupby("episode_full").size().reset_index(name='num_segments')

# %%
plt.figure(figsize=(20, 8))
ax = sns.barplot(data=num_segments, x="episode_full", y="num_segments", palette="viridis")
ax.set_xticks(ax.get_xticks()[::5])  # show every 5th label
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title("Number of segments per episode")
plt.ylabel("n of segments")
plt.xlabel("Episodes")
plt.tight_layout()
plt.show()

# %%
#average duration of scenes per episode for manual segementation
mean_duration = df.groupby("episode_full")["duration"].mean().reset_index()


plt.figure(figsize=(20, 8))
ax = sns.barplot(data=mean_duration, x="episode_full", y="duration", palette="viridis")
ax.set_xticks(ax.get_xticks()[::5])  # show every 5th label
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.title("Average duration of segments per episode")
plt.ylabel("Average duration (s)")
plt.xlabel("Episodes")
plt.tight_layout()
plt.show()

# %%
def boolean_True_plotter(list_of_columns, title, x_label, y_label) :
    counts = df[list_of_columns].sum()
    max_y = counts.max() 

    plt.figure(figsize=(20, 10))
    plt.bar(counts.index, counts.values)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.yticks(np.arange(0, max_y + 50, 50))
    
    plt.show()

# %%
location_columns = ['loc_apt1_Mon_Rach', 'loc_apt2_Chan_Joey', 'loc_apt3_Ross', 'loc_apt4_Pheob_Rach',	'loc_coffeeshop', 'loc_outside', 'loc_other'] 
boolean_True_plotter(location_columns, 'Number of Segments per Location', 'Location', 'Number of segments')

# %%
onbound_columns = ['ONbond_location', 'ONbond_charact_entry', 'ONbond_charact_leave', 'ONbond_time_jump', 'ONbond_goal_change', 'ONbond_music_transit',	'ONbond_theme_song','ONbond_end']
boolean_True_plotter(onbound_columns, 'Number of segments per ONbound type', 'Onbound type', 'Number of segments')

# %%
offbound_columns = ['OFFbond_location',	'OFFbond_charact_entry', 'OFFbond_charact_leave',	'OFFbond_time_jump', 'OFFbond_goal_change',	'OFFbond_music_transit',	'OFFbond_theme_song',	'OFFbond_end']
boolean_True_plotter(offbound_columns, 'Number of segments per OFFbound type', 'Offbound type', 'Number of segments')
